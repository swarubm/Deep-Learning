# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/Deep-Learning-/blob/main/DL03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3. Design and implement a Convolutional Neural Network (CNN) for classification of
# image dataset

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
tf.config.set_visible_devices([], 'GPU')
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
model = models.Sequential([
layers.Input(shape=(32, 32, 3)),
layers.Conv2D(32, (3, 3), activation='relu'),
layers.MaxPooling2D((2, 2)),
layers.Flatten(),
layers.Dense(64, activation='relu'),
layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=5, batch_size=64, validation_split=0.1, verbose=1)
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy:.4f}, Test Loss: {test_loss:.4f}")
y_pred = model.predict(X_test, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)
print(f"Sample Predictions: {y_pred_classes[:5]} (True: {y_test_classes[:5]})")
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 33s 45ms/step - accuracy: 0.3750 - loss: 1.7397 - val_accuracy: 0.5424 - val_loss: 1.3172
# Epoch 2/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 32s 45ms/step - accuracy: 0.5537 - loss: 1.2676 - val_accuracy: 0.5802 - val_loss: 1.2184
# Epoch 3/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 31s 45ms/step - accuracy: 0.5987 - loss: 1.1438 - val_accuracy: 0.5888 - val_loss: 1.1543
# Epoch 4/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.6312 - loss: 1.0508 - val_accuracy: 0.5628 - val_loss: 1.2407
# Epoch 5/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 32s 45ms/step - accuracy: 0.6537 - loss: 0.9934 - val_accuracy: 0.6224 - val_loss: 1.1104
# Test Accuracy: 0.6178, Test Loss: 1.1195
# Sample Predictions: [3 8 8 8 4] (True: [3 8 8 0 6])
